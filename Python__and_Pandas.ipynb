# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielCheu/Learn_pandas_with_Pokemon/blob/main/Python__and_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#bibliotecas
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/GabrielCheu/Learn_pandas_with_Pokemon/main/pokemon_data.csv')

# %%
df.head()
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1          0
# 1  2                Ivysaur  Grass  ...    60           1          0
# 2  3               Venusaur  Grass  ...    80           1          0
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1          0
# 4  4             Charmander   Fire  ...    65           1          0
#
# [5 rows x 12 columns]

# %%
df.tail()
# Out:
#        #                 Name   Type 1  ... Speed  Generation  Legendary
# 795  719              Diancie     Rock  ...    50           6          1
# 796  719  DiancieMega Diancie     Rock  ...   110           6          1
# 797  720  HoopaHoopa Confined  Psychic  ...    70           6          1
# 798  720   HoopaHoopa Unbound  Psychic  ...    80           6          1
# 799  721            Volcanion     Fire  ...    70           6          1
#
# [5 rows x 12 columns]

# %%
df.shape
# Out:
# (800, 12)

# %%
df.describe()
# Out:
#                 #          HP      Attack  ...       Speed  Generation  Legendary
# count  800.000000  800.000000  800.000000  ...  800.000000   800.00000  800.00000
# mean   362.813750   69.258750   79.001250  ...   68.277500     3.32375    0.08125
# std    208.343798   25.534669   32.457366  ...   29.060474     1.66129    0.27339
# min      1.000000    1.000000    5.000000  ...    5.000000     1.00000    0.00000
# 25%    184.750000   50.000000   55.000000  ...   45.000000     2.00000    0.00000
# 50%    364.500000   65.000000   75.000000  ...   65.000000     3.00000    0.00000
# 75%    539.250000   80.000000  100.000000  ...   90.000000     5.00000    0.00000
# max    721.000000  255.000000  190.000000  ...  180.000000     6.00000    1.00000
#
# [8 rows x 9 columns]

# %%
atk = df[['#', 'Name', 'Attack']]
atk.head()
# Out:
#    #                   Name  Attack
# 0  1              Bulbasaur      49
# 1  2                Ivysaur      62
# 2  3               Venusaur      82
# 3  3  VenusaurMega Venusaur     100
# 4  4             Charmander      52

# %%
atk = df[['#', 'Name', 'Attack']].sort_values(by='Attack', ascending=False)
atk.head()
# Out:
#        #                     Name  Attack
# 163  150      MewtwoMega Mewtwo X     190
# 232  214  HeracrossMega Heracross     185
# 424  383    GroudonPrimal Groudon     180
# 426  384    RayquazaMega Rayquaza     180
# 429  386       DeoxysAttack Forme     180

# %%
df.groupby('Type 1').sum()
# Out:
#               #    HP  Attack  Defense  ...  Sp. Def  Speed  Generation  Legendary
# Type 1                                  ...
# Bug       23080  3925    4897     4880  ...     4471   4256         222          0
# Dark      14302  2071    2740     2177  ...     2155   2361         125          2
# Dragon    15180  2666    3588     2764  ...     2843   2657         124         12
# Electric  15994  2631    3040     2917  ...     3243   3718         144          4
# Fairy      7642  1260    1046     1117  ...     1440    826          70          1
# Fighting   9824  1886    2613     1780  ...     1747   1784          91          0
# Fire      17025  3635    4408     3524  ...     3755   3871         167          5
# Flying     2711   283     315      265  ...      290    410          22          2
# Ghost     15568  2062    2361     2598  ...     2447   2059         134          2
# Grass     24141  4709    5125     4956  ...     4930   4335         235          3
# ...

# %%
df.groupby('Type 1').max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   """Entry point for launching an IPython kernel.
#             #                   Name   HP  ...  Speed  Generation  Legendary
# Type 1                                     ...
# Bug       666                Yanmega   86  ...    160           6          0
# Dark      717               Zweilous  126  ...    125           6          1
# Dragon    718       Zygarde50% Forme  125  ...    120           6          1
# Electric  702              Zebstrika   90  ...    140           6          1
# Fairy     716                Xerneas  126  ...     99           6          1
# Fighting  701                Tyrogue  144  ...    118           6          0
# ...

# %%
df.loc[20:25]
# Out:
#      #                 Name  Type 1  ... Speed  Generation  Legendary
# 20  16               Pidgey  Normal  ...    56           1          0
# 21  17            Pidgeotto  Normal  ...    71           1          0
# 22  18              Pidgeot  Normal  ...   101           1          0
# 23  18  PidgeotMega Pidgeot  Normal  ...   121           1          0
# 24  19              Rattata  Normal  ...    72           1          0
# 25  20             Raticate  Normal  ...    97           1          0
#
# [6 rows x 12 columns]

# %%
df.loc[df['Generation']==3]
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 272  252                Treecko    Grass  ...    70           3          0
# 273  253                Grovyle    Grass  ...    95           3          0
# 274  254               Sceptile    Grass  ...   120           3          0
# 275  254  SceptileMega Sceptile    Grass  ...   145           3          0
# 276  255                Torchic     Fire  ...    45           3          0
# ..   ...                    ...      ...  ...   ...         ...        ...
# 427  385                Jirachi    Steel  ...   100           3          1
# 428  386     DeoxysNormal Forme  Psychic  ...   150           3          1
# 429  386     DeoxysAttack Forme  Psychic  ...   150           3          1
# 430  386    DeoxysDefense Forme  Psychic  ...    90           3          1
# 431  386      DeoxysSpeed Forme  Psychic  ...   180           3          1
#
# [160 rows x 12 columns]

# %%
df.loc[df['Type 1'] == 'Dragon', ["#","Name","Attack"]].head()
# Out:
#        #                 Name  Attack
# 159  147              Dratini      64
# 160  148            Dragonair      84
# 161  149            Dragonite     134
# 365  334              Altaria      70
# 366  334  AltariaMega Altaria     110

# %%
#criando pokemon Cheumander
new_pokemon = {'#':['800'], 'Name':['Cheumander'], 'Type 1':['Dragon'],'Attack':['200'], 'Legendary':['1']}
poke_df = pd.DataFrame(new_pokemon)
poke_df.head()
# Out:
#      #        Name  Type 1 Attack Legendary
# 0  800  Cheumander  Dragon    200         1

# %%
#adicionando linha
df = df.append(poke_df)
df.tail()
# Out:
#        #                 Name   Type 1  ...  Speed  Generation Legendary
# 796  719  DiancieMega Diancie     Rock  ...  110.0         6.0         1
# 797  720  HoopaHoopa Confined  Psychic  ...   70.0         6.0         1
# 798  720   HoopaHoopa Unbound  Psychic  ...   80.0         6.0         1
# 799  721            Volcanion     Fire  ...   70.0         6.0         1
# 0    800           Cheumander   Dragon  ...    NaN         NaN         1
#
# [5 rows x 12 columns]

# %%
#deletando linha
df = df.drop(0, axis=0)
df.tail()
# Out:
#        #                 Name   Type 1  ...  Speed  Generation Legendary
# 795  719              Diancie     Rock  ...   50.0         6.0         1
# 796  719  DiancieMega Diancie     Rock  ...  110.0         6.0         1
# 797  720  HoopaHoopa Confined  Psychic  ...   70.0         6.0         1
# 798  720   HoopaHoopa Unbound  Psychic  ...   80.0         6.0         1
# 799  721            Volcanion     Fire  ...   70.0         6.0         1
#
# [5 rows x 12 columns]
